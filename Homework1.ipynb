# %% [markdown]
# # Bài tập về nhà tuần 1

# %%
import math
x = 1.1 + 2.2
print(x == 0)
print(1.1 + 2.2)
print ("-"*30)
print(math.isclose(x, 3.3))
# Out:
# False
# 3.3000000000000003
# ------------------------------
# True

# %% [markdown]
# ### Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
a = int(input())
print(a*2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 a = int(input())
#       2 print(a*2)
#
# ValueError: invalid literal for int() with base 10: 'q'

# %% [markdown]
# ### Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a, b = map(int, input().split())
r = a / 2
s = (a * b) - (r ** 2 * 3.14)
print(f"{s:.2f}")
# Out:
# 2.86

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
text = input()
if text.isupper():
    print(text.lower())
elif text.islower():
    print(text.upper())
else:
    print("Kí tự không phải chữ hoa cũng không phải chữ thường")
# Out:
# h

# %% [markdown]
# ### Bài 4:  Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = input()
if c.isalpha():
    print(f"{c} là kí tự alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")
# Out:
# ấ là kí tự alphabet

# %% [markdown]
# ### Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if c == 'A':
    print('Không có kí tự nào đằng trước A')
else:
    print(chr(ord(c.lower()) - 1))
# Out:
# Không có kí tự nào đằng trước A

# %% [markdown]
# ### Bài 6: Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c = map(int, input().split())
if (a+b) > c and (a+c) > b and (b+c) > a:
    p = (a+b+c) / 2
    s = (p*(p-a)*(p-b)*(p-c))**0.5
    print(f"{s:.1f}")
else:    print("Không phải 3 cạnh của tam giác")
# Out:
# 2.9

# %% [markdown]
# ### Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
s = input().strip()
if len(s) < 20:
    print("Chuỗi quá ngắn")
else: 
    print(s[4], s[8])
# Out:
# k h

# %% [markdown]
# ### Bài 8:Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:  -
# ### Từ 0 – 50kWh: 1.984 đồng/kWh  - - - - -
# #### Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# #### Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# #### Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# #### Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# #### Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# ### Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
name = input("Tên chủ hộ")
old = int(input("Chỉ số tháng trước"))
new = int(input("Chỉ số tháng này"))
kwh = new - old
money = 0
if kwh <= 50:
    money = kwh * 1984
elif kwh <= 100:
    money = 50 * 1984 + (kwh - 50) * 2050
elif kwh <= 200:
    money = 50 * 1984 + 50 * 2050 + (kwh - 100) * 2380
elif kwh <= 300:
    money = 50 * 1984 + 50 * 2050 + 100 * 2380 + (kwh - 200) * 2998
elif kwh <= 400:
    money = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (kwh - 300) * 3350
else:
    money = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (kwh - 400) * 3460
sum = money * 1.08
print(f"Họ và tên: {name}")
print(f"Tiền phải trả là: {round(sum)} đồng")
# Out:
# Họ và tên: Bao
# Tiền phải trả là: 1892873 đồng

# %% [markdown]
# # Các bài tập khác

# %% [markdown]
# ### 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó là số chẵn hay số lẻ.

# %%
num = int(input("Nhập một số nguyên: "))
if num % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Số lẻ

# %% [markdown]
# ### 2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
num = int(input("Nhập một số nguyên: "))
last_digit = 5 
if num % 10 == last_digit:
    print(f"True")
else:
    print(f"False")
# Out:
# False

# %% [markdown]
# ### 3. Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
num = int(input())
if num % 3 == 0 and num % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ### 4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
age = int(input())
if age <= 18:
    print ("Bạn chưa đủ tuổi để đi bầu cử")
else:   print ("Bạn đã đủ tuổi để đi bầu cử")
# Out:
# Bạn chưa đủ tuổi để đi bầu cử

# %% [markdown]
# ### 5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau.

# %%
a = int(input())
b = int(input())
if a > b:
    print(a)
elif a < b:
    print(b)
else:
    print("Hai số bằng nhau")
# Out:
# 7

# %% [markdown]
# ### 6. Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số.

# %%
c = input()
if c.isalpha():
    print(f"{c} là kí tự alphabet")
elif c.isdigit():
    print(f"{c} là kí tự số")
else :
    print(f"{c} không phải là kí tự alphabet cũng không phải là kí tự số")
# Out:
# fkaslkasdjbg23 không phải là kí tự alphabet cũng không phải là kí tự số

# %% [markdown]
# ### 7. Bài tập 5: Tính điểm học lực
# #### Nhập điểm (0-10), phân loại học lực theo quy tắc:
# #### >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
n = float(input("Nhập điểm: "))
if n >= 8:
    print("Học lực giỏi")
elif n >= 6.5 and n < 8:
    print("Học lực khá")
elif n < 6.5 and n >= 5:
    print("Học lực trung bình")
elif n < 5:
    print("Học lực yếu")
# Out:
# Học lực khá

# %% [markdown]
# ### 8. Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4 nhưng không chia hết cho 100)

# %%
year = float(input("Nhập năm: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{int(year)} là năm nhuận")
else:
    print(f"{int(year)} không phải là năm nhuận")
# Out:
# 3600 là năm nhuận

# %% [markdown]
# ### 9. Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
n = int(input())
match n:
    case 0:
        print("Không")
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
    case n if n > 9 or n < 0:
        print("Số không hợp lệ")
# Out:
# Số không hợp lệ

# %% [markdown]
# ### 10. Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >= 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
n = float(input())
if n >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Qua môn

# %% [markdown]
# ### 11. Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
n = float(input())
age = 2025 - n
if age < 18:
    print("False")
else:    print("True")
# Out:
# True
