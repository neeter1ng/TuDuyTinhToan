# %% [markdown]
# ### W1A1
# #### In ra dòng chữ "Hello World"

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ### W1A2
# #### Nhập tên người nào đó và in ra lời chào

# %%
name = input()
print(f"Hi {name}")
# Out:
# Hi bao
